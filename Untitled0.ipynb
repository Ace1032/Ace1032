# %% [markdown]
# <a href="https://colab.research.google.com/github/Ace1032/Ace1032/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, numpy as np, numba
from numba import cuda
print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Numba:", numba.__version__)
print("CUDA available:", cuda.is_available())
if cuda.is_available():
    print("Device:", cuda.get_current_device().name)
# Out:
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# NumPy: 2.0.2
# Numba: 0.60.0
# CUDA available: True
# Device: b'Tesla T4'
